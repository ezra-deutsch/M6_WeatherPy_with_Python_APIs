# %%
#6.1.4
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#4. Get the nearest city using the citipy module.
#6.1.5
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
#3. Create a new set of 2,000 random latitudes and longitudes.
#6.1.5
lats = np.random.uniform(-90.000,90.000, size=50)
lngs = np.random.uniform(-180.000,180.000, size=50)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
#6.1.5
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
coordinates
# Out:
# [(69.32042336192359, -168.81061803725405),
#  (-3.956675837482379, -166.38593037170725),
#  (-53.61590131641311, 10.502580899465613),
#  (34.16977987127345, 163.0068512612362),
#  (-84.99794985563874, -170.08995160514314),
#  (87.65870117791584, 72.73543994191994),
#  (31.73252916038858, 32.390014472290005),
#  (-47.25807967374588, -73.85226315768833),
#  (-24.486659615818013, -84.81865063314622),
#  (51.74567575799378, -40.93802344072381),
#  (63.35623226154806, 54.23993302233404),
#  (-29.41706178864885, 48.25801867615766),
#  (-55.785324418109646, 52.214823789194924),
#  (-10.869018070200752, 34.86735810026042),
#  (-80.12672830297625, 6.5825749301955625),
#  (-23.36268153582087, -56.31368216788607),
#  (68.75137121606036, 161.46306822561297),
#  (47.71074826144863, -123.04093227569459),
#  (39.312743118636575, 35.346683234202885),
#  (-66.91394535148503, -70.04561526780316),
#  (-78.50141347970393, 10.292461677954236),
#  (17.19949973763981, 159.87190759562253),
#  (-74.61603465005862, 73.45550082822353),
#  (-55.49374643522976, 112.37893406462763),
#  (58.048640331351805, 178.44409034725322),
#  (76.34378582156538, -72.1403682949743),
#  (-19.04235032667819, 173.5825347350377),
#  (-52.28652943242525, -48.1178098469957),
#  (73.11171680119355, -70.98164897338522),
#  (-19.432784929965848, -179.56713567141477),
#  (-1.623042007905653, 65.25199586526304),
#  (77.9192168628768, -105.85904353572148),
#  (-77.06359311948135, -70.98069826227689),
#  (-59.141311408960654, 139.71699085568662),
#  (-23.62480485324818, -39.60538897238254),
#  (-10.908368534959322, -159.8613942356817),
#  (68.77723756812134, 114.32618817803478),
#  (3.6203540057813655, 76.9209346559424),
#  (-86.11579448861109, -179.1388778272787),
#  (-18.398848279381724, 55.83994857859892),
#  (-16.694270258702133, -82.81751468569645),
#  (4.638200612641668, -179.80443761992342),
#  (-4.910050934486378, -61.96363700814629),
#  (23.209498837078726, -6.739010450843608),
#  (-43.45598308890045, -171.85515936269064),
#  (-14.33484970784346, 150.25006650867067),
#  (-88.31726561881263, 148.51802004939913),
#  (77.34759230479992, -111.8407589090582),
#  (-44.01136080016624, 129.47347949379105),
#  (-64.70489799093133, 107.07830854968768)]

# %%
#6.1.5
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 41

# %%
#5. Perform an API call with the OpenWeatherMap.
#6.2.6
#Import dependencies (requests)
import requests
# Import the datetime module from the datetime library.
from datetime import datetime

#import the API key
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#6.2.6
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
#6.2.6
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lavrentiya
# Processing Record 2 of Set 1 | lufilufi
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | severo-kurilsk
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | port said
# Processing Record 8 of Set 1 | coihaique
# Processing Record 9 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 1 | nanortalik
# Processing Record 11 of Set 1 | sosnogorsk
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | matiri
# Processing Record 14 of Set 1 | tacuati
# Processing Record 15 of Set 1 | cherskiy
# Processing Record 16 of Set 1 | bremerton
# Processing Record 17 of Set 1 | sorgun
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | beringovskiy
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | isangel
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | clyde river
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | armacao dos buzios
# City not found. Skipping...
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | udachnyy
# Processing Record 33 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 34 of Set 1 | grand baie
# Processing Record 35 of Set 1 | pisco
# Processing Record 36 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 1 | codajas
# Processing Record 38 of Set 1 | taoudenni
# Processing Record 39 of Set 1 | samarai
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | port lincoln
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#7. Add the data to a new DataFrame.
#6.2.7
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Lavrentiya  65.5833 -171.0000     38.86        69          99
# 1        Lufilufi -13.8745 -171.5986     80.78        75          11
# 2        Hermanus -34.4187   19.2345     54.81        75           0
# 3  Severo-Kurilsk  50.6789  156.1250     51.96        67          20
# 4           Vaini -21.2000 -175.2000     76.26        82           3
# 5          Dikson  73.5069   80.5464     33.80        72          42
# 6       Port Said  31.2565   32.2841     79.03        59           0
# 7       Coihaique -45.5752  -72.0662     41.43        92          80
# 8      Nanortalik  60.1432  -45.2371     37.94        83          21
# 9      Sosnogorsk  63.6023   53.8817     38.64        72          92
#
#    Wind Speed Country                 Date
# 0        9.60      RU  2021-09-17 21:38:52
# 1       18.16      WS  2021-09-17 21:38:52
# 2       20.31      ZA  2021-09-17 21:32:22
# 3        7.23      RU  2021-09-17 21:30:07
# 4        9.44      TO  2021-09-17 21:30:59
# 5       20.20      RU  2021-09-17 21:38:53
# 6        9.53      EG  2021-09-17 21:38:54
# 7        7.14      CL  2021-09-17 21:38:54
# 8       19.75      GL  2021-09-17 21:38:55
# 9       13.11      RU  2021-09-17 21:38:55
